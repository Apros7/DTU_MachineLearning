# %%
import pandas as pd
import numpy as np
import awoc
from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("../LifeExpectancyData.csv")
cov_matrix = data.cov()
diagonal = np.sqrt(np.diag(cov_matrix))
normalized_cov_matrix = cov_matrix / (diagonal[:, np.newaxis] * diagonal)
plt.figure(figsize=(8, 6))
sns.heatmap(normalized_cov_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=1, cbar=False,
            annot_kws={"size": 6})
plt.title('Covariance Matrix Heatmap', fontsize=14)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.show()
# Out:
# /var/folders/pl/7f1cr2657p3bnpdt3bnm_9w00000gn/T/ipykernel_28835/2442476663.py:2: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cov_matrix = data.cov()

# %%
data = pd.read_csv("StandardizedDataFrameWithNansFilled.csv")
cov_matrix = data.cov()
diagonal = np.sqrt(np.diag(cov_matrix))
normalized_cov_matrix = cov_matrix / (diagonal[:, np.newaxis] * diagonal)
plt.figure(figsize=(8, 6))
sns.heatmap(normalized_cov_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=1, cbar=False,
            annot_kws={"size": 6})
plt.title('Covariance Matrix Heatmap', fontsize=14)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.show()
# Out:
# /var/folders/pl/7f1cr2657p3bnpdt3bnm_9w00000gn/T/ipykernel_28835/266128860.py:2: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cov_matrix = data.cov()

# %% [markdown]
# It the same, as it should be :D
