# %%
import pandas as pd
import numpy as np
import awoc
from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("../LifeExpectancyData.csv")
data["Status"] = [1 if stat == "Developed" else 0 for stat in data["Status"]]
data = data.drop(columns=["Country", "Year"])
data.head()
# Out:
#    Status  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0       0              65.0            263.0             62     0.01
# 1       0              59.9            271.0             64     0.01
# 2       0              59.9            268.0             66     0.01
# 3       0              59.5            272.0             69     0.01
# 4       0              59.2            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   under-five deaths   \
# 0               71.279624         65.0      1154   19.1                  83
# 1               73.523582         62.0       492   18.6                  86
# 2               73.219243         64.0       430   18.1                  89
# 3               78.184215         67.0      2787   17.6                  93
# 4                7.097109         68.0      3013   17.2                  97
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5

# %%
cov_matrix = data.cov()
diagonal = np.sqrt(np.diag(cov_matrix))
normalized_cov_matrix = cov_matrix / (diagonal[:, np.newaxis] * diagonal)
plt.figure(figsize=(8, 6))
sns.heatmap(normalized_cov_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=1, cbar=False,
            annot_kws={"size": 6})
plt.title('Covariance Matrix Heatmap', fontsize=14)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.show()

# %%
data = pd.read_csv("StandardizedDataFrameWithNansFilled.csv")
data["Status"] = [1 if stat == "Developed" else 0 for stat in data["Status"]]
data = data.drop(columns=["Country", "Year"])
data.head()
# Out:
#    Unnamed: 0  Status  Life expectancy   Adult Mortality  infant deaths  \
# 0           0       0         -0.444372         0.791452       0.268778
# 1           1       0         -0.980783         0.855926       0.285738
# 2           2       0         -0.980783         0.831748       0.302697
# 3           3       0         -1.022854         0.863985       0.328137
# 4           4       0         -1.054408         0.888163       0.345097
#
#     Alcohol  percentage expenditure  Measles       BMI   under-five deaths   \
# 0 -1.139938               -0.335513 -0.110366 -0.964550            0.255316
# 1 -1.139938               -0.334384 -0.168095 -0.989641            0.274014
# 2 -1.139938               -0.334537 -0.173502 -1.014732            0.292712
# 3 -1.139938               -0.332040  0.032040 -1.039823            0.317642
# 4 -1.139938               -0.367800  0.051748 -1.059895            0.342573
#
#       Polio  Total expenditure  Diphtheria    HIV/AIDS   thinness  1-19 years  \
# 0 -3.254219           0.911749    -0.723742   -0.32339               2.812651
# 1 -1.039197           0.919893    -0.850094   -0.32339               2.880918
# 2 -0.868811           0.899533    -0.765859   -0.32339               2.926429
# 3 -0.655828           1.058344    -0.639507   -0.32339               2.971940
# 4 -0.613232           0.793659    -0.597390   -0.32339               3.040207
#
#     thinness 5-9 years  Income composition of resources  Schooling
# 0             2.772807                        -0.725277  -0.579832
# 1             2.817423                        -0.739924  -0.610466
# 2             2.862039                        -0.769218  -0.641099
# 3             2.928963                        -0.803395  -0.671733
# 4             2.973578                        -0.847336  -0.763634

# %%
cov_matrix = data.cov()
diagonal = np.sqrt(np.diag(cov_matrix))
normalized_cov_matrix = cov_matrix / (diagonal[:, np.newaxis] * diagonal)
plt.figure(figsize=(8, 6))
sns.heatmap(normalized_cov_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=1, cbar=False,
            annot_kws={"size": 6})
plt.title('Covariance Matrix Heatmap', fontsize=14)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.show()

# %% [markdown]
# It the same, as it should be :D
